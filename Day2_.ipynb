# %% [markdown]
# <a href="https://colab.research.google.com/github/ShanakGanta/Data-Science-Journey-2026/blob/main/Day2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
                                        #Coditional statements:
                                                #If,If-Else,Elif,Else-If Ladder,Nested If
#1. If
a=5
if (a>3):
  print("Tt is greater")

#2. If-Else
a=10
b=5
result=a+b
if(result>20):
  print("It is greater")
else:
    print("It is lesser")

#3. Else-If ladder
a=15
b=20
c=14
if(a>=20):
  print("Ok a")
elif(b>=20):
    print("Ok b")
elif(c>=20):
    print("Ok c")
else:
    print("everything is lower than 20")

#Nested If
a=50
b=60
c=55
if(a>b):
  if(a>c):
    print("A is Greater")
  else:
      print("C is Greater")
elif(b>c):
      print("B is Greater")
else:
      print("C is Greater")
# Out:
# Tt is greater
# It is lesser
# Ok b
# B is Greater
