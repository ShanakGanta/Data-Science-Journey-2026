# %% [markdown]
# <a href="https://colab.research.google.com/github/ShanakGanta/Data-Science-Journey-2026/blob/main/Project_1_day_one_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
product = input("Enter the product: ")
price = float(input("Enter the price: "))
quantity = int(input("Enter the quantity: "))

subtotal = price * quantity
tax = subtotal * 0.18

discount = 0
discount = (subtotal // 500) * 100

total_amount = subtotal + tax - discount

print("Product:", product)
print("Subtotal:", subtotal)
print("Tax:", tax)
print("Discount:", discount)
print("Total Amount:", total_amount)
# Out:
# Enter the product: Goats
# Enter the price: 5000
# Enter the quantity: 15
# Product: Goats
# Subtotal: 75000.0
# Tax: 13500.0
# Discount: 15000.0
# Total Amount: 73500.0
